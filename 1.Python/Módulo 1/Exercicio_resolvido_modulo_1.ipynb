# %% [markdown]
# # 1. Google Colab

# %%
print("Olá, mundo!")
# Out:
# Olá, mundo!

# %% [markdown]
# ![1_mRKZnV1DJA_2p3bBpLnMYw.png](data:image/png;base64,...)

# %% [markdown]
# # 2. Números
#
# Tk = Svv/Sqv

# %%
valor_total_de_vendas = ("A")
qtd_total_vendas = 3
tkt_medio = 320.52

valor_total_de_vendas = qtd_total_vendas*tkt_medio
print(total_de_vendas)
# Out:
# 961.56

# %%
qtd_total_vendas = ("B")
valor_total_de_vendas = 834.47
tkt_medio = 119.21

qtd_total_vendas = valor_total_de_vendas/tkt_medio
print(int(qtd_total_vendas))
# Out:
# 7

# %%
tkt_medio = ("C")
qtd_total_vendas = 5
valor_total_vendas = 15378.12

tkt_medio = valor_total_vendas/qtd_total_vendas
print(tkt_medio)
# Out:
# 3075.6240000000003

# %% [markdown]
# ### (A) R$ 961,56

# %% [markdown]
# ####(B) 7

# %% [markdown]
# ####(C) R$ 3075,62

# %% [markdown]
# ## **3. Strings**

# %%
cancao = 'roda mundo, roda gigante, roda moinho, roda pião.'
maiuscula = cancao.capitalize()
print(maiuscula)
# Out:
# Roda mundo, roda gigante, roda moinho, roda pião.

# %%
cancao = 'roda mundo, roda gigante, roda moinho, roda pião.'
substituir = cancao.replace ('roda', 'capota')
print(substituir)
# Out:
# capota mundo, capota gigante, capota moinho, capota pião.

# %%
cancao = 'RODA MUNDO, RODA GIGANTE, RODA MOINHO, RODA PIÃO.'
minuscula = cancao.casefold()
print(minuscula)
# Out:
# roda mundo, roda gigante, roda moinho, roda pião.

# %%
noticia = 'Selic vai a 2,75% e supera expectativas; é a primeira alta em 6 anos.'
selic = noticia[12:18]
print(selic)

ano = noticia[62:68]
print(ano)
# Out:
# 2,75%
# 6 anos

# %% [markdown]
# # 4. Booleanos

# %%
a = True
b = False
x = not a & b

print(x)
# Out:
# True
